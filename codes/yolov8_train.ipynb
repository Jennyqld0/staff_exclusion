# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/staff_exclusion/
# Out:
# /content/drive/MyDrive/staff_exclusion

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 793.0/793.0 kB 11.7 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
# !yolo train model=yolov8s.pt data="/content/drive/MyDrive/staff_exclusion/dataset/data.yaml" epochs=150 imgsz=640
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 232MB/s]
# Ultralytics YOLOv8.2.41 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !python codes/predict.py
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# 0: 480x640 (no detections), 9.2ms
# Speed: 2.7ms preprocess, 9.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.3ms
# Speed: 3.2ms preprocess, 7.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.0ms
# Speed: 2.9ms preprocess, 6.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 people, 5.9ms
# Speed: 2.8ms preprocess, 5.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 people, 5.9ms
# Speed: 2.6ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 people, 5.9ms
# Speed: 2.7ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 people, 7.7ms
# Speed: 3.1ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 people, 5.8ms
# ...
